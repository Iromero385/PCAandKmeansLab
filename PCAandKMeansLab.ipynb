# %% [markdown]
# <a href="https://colab.research.google.com/github/Iromero385/PCAandKmeansLab/blob/main/PCAandKMeansLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab Sections:

# %% [markdown]
# ##Loading Data Tools

# %%
# File management
from google.colab import drive
drive.mount('/content/drive')

# Data manipulations
import pandas as pd
import numpy as np

# PCA Analysis
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# kmeans clustering
from sklearn.cluster import KMeans

# Graphing
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Access files on the left margin.

# %% [markdown]
# ![Screen Shot 2025-06-05 at 11.02.51 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## Find the file path.

# %% [markdown]
# ![Screen Shot 2025-06-05 at 11.16.55 PM.png](data:image/png;base64,...)

# %%
#adjust file path to reflect file FoodDeserts.csv
file_path = "/content/drive/MyDrive/Data Science Book Chapter 2024/Data/Food_Deserts_Data.csv"
#read text file into pandas DataFrame
food_deserts_data= pd.read_csv(file_path, sep=",")

food_deserts_data.shape
# Out:
# (72531, 147)
